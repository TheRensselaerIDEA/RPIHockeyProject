# %% [markdown]
# # Identifying Known Rink Locations
# The objective of this program is to identify known rink locations and learn how to identify them on a sequence of images.

# %%
import os 
import sys
import tensorflow as tf                                                                                        
import numpy as np  
import pandas as pd
# import pickle                                                                   
# import matplotlib as mpl
# #mpl.use('Agg')
import matplotlib.pyplot as plt   
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
# #import matplotlib.axes as ax
# from sklearn.metrics import confusion_matrix    
# import itertools
# import scipy.misc
# import imageio
import json
import cv2
# %load_ext autoreload

# %aimport helper

#download inception for its transfer layer
import inception
inception.maybe_download()

SRC_PATH = os.path.abspath("./")

from time import time
# Out:
# Downloading Inception v3 Model ...
# Data has apparently already been downloaded and unpacked.

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'   
JSON_DIR = os.path.abspath("./")
IMAGE_DIR = os.path.join(SRC_PATH, "./images")
stime = time()

# %% [markdown]
# ### Load the json labels
# The json file contains all labeled rink locations, and labels not in the images should be labeled as (-1,-1)

# %% [markdown]
# ### Declare list of labels to predict
# Out of the possible known rink locations, these are the ones that appear in our dataset

# %%
known_rink_locs = ['Red Line', 
                    'Red Line Bottom',
                'Right Blue Line', 
                    'Right Blue Line Bottom', 
                    'Left Blue Line', 
                    'Left Blue Line Bottom',
                'Right Goal Line', 
                    'Right Goal Line Bottom', 
                    'Left Goal Line',
                    'Left Goal Line Bottom',
                'Center ice',
                'Right Top Neutral Faceoff Dot',
                    'Right Bottom Neutral Faceoff Dot',
                    'Left Top Neutral Faceoff Dot',
                    'Left Bottom Neutral Faceoff Dot',
                'Right Top Zone Faceoff Dot',
                    'Right Bottom Zone Faceoff Dot',
                    'Left Top Zone Faceoff Dot',
                    'Left Bottom Zone Faceoff Dot',
                'Right Top Goal Post',
                    'Right Bottom Goal Post',
                    'Left Top Goal Post',
                    'Left Bottom Goal Post',
                'Left Top Hash-Left Inner Hash Mark',
                    'Left Top Hash-Right Inner Hash Mark',
                    'Left Bottom Hash-Left Inner Hash Mark',
                    'Left Bottom Hash-Right Inner Hash Mark',
                    'Right Top Hash-Left Inner Hash Mark',
                    'Right Top Hash-Right Inner Hash Mark',
                    'Right Bottom Hash-Left Inner Hash Mark',
                    'Right Bottom Hash-Right Inner Hash Mark']
print(len(known_rink_locs))
known_rink_loc_set = set(known_rink_locs)

D = len(known_rink_locs)
key_loc_pairs = {'Red Line': 0, 
                    'Red Line Bottom':1,
                'Right Blue Line': 2, 
                    'Right Blue Line Bottom': 3, 
                    'Left Blue Line': 4, 
                    'Left Blue Line Bottom': 5,
                'Right Goal Line': 6, 
                    'Right Goal Line Bottom': 7, 
                    'Left Goal Line': 8,
                    'Left Goal Line Bottom': 9,
                'Center ice': 10,
                'Right Top Neutral Faceoff Dot': 11,
                    'Right Bottom Neutral Faceoff Dot': 12,
                    'Left Top Neutral Faceoff Dot':13,
                    'Left Bottom Neutral Faceoff Dot':14,
                'Right Top Zone Faceoff Dot': 15,
                    'Right Bottom Zone Faceoff Dot':16,
                    'Left Top Zone Faceoff Dot': 17,
                    'Left Bottom Zone Faceoff Dot': 18,
                'Right Top Goal Post': 19,
                    'Right Bottom Goal Post': 20,
                    'Left Top Goal Post': 21,
                    'Left Bottom Goal Post': 22,
                'Left Top Hash-Left Inner Hash Mark': 23,
                    'Left Top Hash-Right Inner Hash Mark': 24,
                    'Left Bottom Hash-Left Inner Hash Mark': 25,
                    'Left Bottom Hash-Right Inner Hash Mark': 26,
                    'Right Top Hash-Left Inner Hash Mark': 27,
                    'Right Top Hash-Right Inner Hash Mark': 28,
                    'Right Bottom Hash-Left Inner Hash Mark':29,
                    'Right Bottom Hash-Right Inner Hash Mark':30}
print(len(key_loc_pairs.keys()))
assert (len(key_loc_pairs.keys()) == len(known_rink_locs))
for key in key_loc_pairs.keys():
    loc = key_loc_pairs[key]
    assert known_rink_locs[loc] == key
# Out:
# 31
# 31

# %% [markdown]
# ## Inception
# We will use the second last layer of inception as the input to the LSTM network.  This way, we can "understand" the input images, without the need to train on LARGE amounts of data

# %%
#use this model to get the transfer layer for detecting image similarities
model = inception.Inception()

#use this command to get the transfer layer values of the image
# model_TL.transfer_values(image= gt_im)

# %% [markdown]
# ### Weights
# Define weights to output layer from transfer layer

# %%
#Define Variable Functions
def weight_variable(name, shape):
    #initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.get_variable(name, shape=shape,
                            initializer=tf.contrib.layers.xavier_initializer())

def bias_variable(shape):
    initial = tf.constant(0.0, shape=shape)
    return tf.Variable(initial)

# %% [markdown]
# ### Data split into test and train
# Separate data for preparation to training

# %%
# print "Splitting data into Training and Validation Sets"
# sDTrainValSplitTime = time()
# testSet = True
# valPercent = .2  #.11
# seed = 42
# xTrain, xVal, yTrain, yVal = train_test_split(xData, yData, test_size= valPercent, random_state= seed, shuffle= True)
# if testSet:
#     testPercent = .3 #taken from valset

# %% [markdown]
# ### JSON Parsing
# Preepare the y-data labels from json file.  The xy labels in the image should be defined as their ground truth locations, while xy locations not in the frame should be defined as a variable $v*(-1,-1)$

# %%
def json_parser(json_name, key_loc_pairs, D, not_found_val =-1):
    '''
    @param json_name str of filename to open and read in a json file with rink locations 
    @param D the length of the known rink locations

    @return image_list[str] a list of all labeled image file names
    @return in_image[bool] whether each point is in the image
    '''
    with open(json_name) as f:
        data = json.load(f)

    # convert json to pandas dataframe
    data = pd.DataFrame(data)

    # remove skipped images
    data = data[data.Label != 'Skip']

    # remove images that don't have updated naming convention
    elim_lst = ["RushPlay_" in frame_name for frame_name in data["External ID"]]
    data = data[elim_lst]
    data = data.reset_index(drop=True)
    
    # N data points we can work with
    N = len(data['External ID'])

    # convert to list of image filenames
    image_list = data['External ID'].tolist()

#     print(data['Label'])
    
    # define gt_data structure and set to (not found)
    rink_locs = np.zeros((N, D, 2)) + not_found_val
    in_image = np.zeros((N,D), dtype= bool)

    
    for i in range(N):
        # Getting the height of the image
#         im_dir = os.path.abspath(rush_play + ids[i])
#         im = cv2.imread(im_dir)
#         height = len(im)
        
        '''
        for feature in data['Label'][i]:
            if (feature in loc_index):
                # setting the x coord
                rink_locs[i, loc_index[feature], 0] = features[i][feature][0]['geometry']['x']
                # setting the y coord
                rink_locs[i, loc_index[feature], 1] = features[i][feature][0]['geometry']['y']  
        '''
        for feature in key_loc_pairs.keys():
            if feature in data['Label'][i]:
                rink_locs[i, key_loc_pairs[feature], 0] = data['Label'][i][feature][0]['geometry']['x']
                # setting the y coord
                rink_locs[i, key_loc_pairs[feature], 1] = data['Label'][i][feature][0]['geometry']['y']
                in_image[i, key_loc_pairs[feature]] = 1
            '''else:
                rink_locs[i, key_loc_pairs[feature], 0] = not_found_val
                rink_locs[i, key_loc_pairs[feature], 1] = not_found_val
'''
    return image_list, in_image, rink_locs

# %%
def statistics(rink_locs, key_loc_pairs):
    print("Percentage of points found:")
    
    for feature in key_loc_pairs.keys():
        rows, cols = np.where(rink_locs[:,key_loc_pairs[feature],:] != np.array([-1.,-1.], dtype = np.float))
#         print(rows)
#         print(cols)
        num = len(rows)//2 #np.count_nonzero(rink_locs[rows,key_loc_pairs['Right Goal Line'],cols]) // 2
        print("{}: {:.1f}%  ({}/{})".format(feature, 100*num/len(rink_locs), num, len(rink_locs)))

# %%
image_list, y_in_image, rink_locs = json_parser(os.path.join(SRC_PATH, 'RushPlays.json'), key_loc_pairs, D, not_found_val= -100)

statistics(rink_locs, key_loc_pairs)
# Out:
# Percentage of points found:
# Red Line: 100.0%  (131/131)
# Red Line Bottom: 100.0%  (131/131)
# Right Blue Line: 100.0%  (131/131)
# Right Blue Line Bottom: 100.0%  (131/131)
# Left Blue Line: 100.0%  (131/131)
# Left Blue Line Bottom: 100.0%  (131/131)
# Right Goal Line: 100.0%  (131/131)
# Right Goal Line Bottom: 100.0%  (131/131)
# Left Goal Line: 100.0%  (131/131)
# Left Goal Line Bottom: 100.0%  (131/131)
# Center ice: 100.0%  (131/131)
# Right Top Neutral Faceoff Dot: 100.0%  (131/131)
# Right Bottom Neutral Faceoff Dot: 100.0%  (131/131)
# Left Top Neutral Faceoff Dot: 100.0%  (131/131)
# Left Bottom Neutral Faceoff Dot: 100.0%  (131/131)
# Right Top Zone Faceoff Dot: 100.0%  (131/131)
# Right Bottom Zone Faceoff Dot: 100.0%  (131/131)
# Left Top Zone Faceoff Dot: 100.0%  (131/131)
# Left Bottom Zone Faceoff Dot: 100.0%  (131/131)
# Right Top Goal Post: 100.0%  (131/131)
# Right Bottom Goal Post: 100.0%  (131/131)
# Left Top Goal Post: 100.0%  (131/131)
# Left Bottom Goal Post: 100.0%  (131/131)
# Left Top Hash-Left Inner Hash Mark: 100.0%  (131/131)
# Left Top Hash-Right Inner Hash Mark: 100.0%  (131/131)
# Left Bottom Hash-Left Inner Hash Mark: 100.0%  (131/131)
# Left Bottom Hash-Right Inner Hash Mark: 100.0%  (131/131)
# Right Top Hash-Left Inner Hash Mark: 100.0%  (131/131)
# Right Top Hash-Right Inner Hash Mark: 100.0%  (131/131)
# Right Bottom Hash-Left Inner Hash Mark: 100.0%  (131/131)
# Right Bottom Hash-Right Inner Hash Mark: 100.0%  (131/131)

# %%
# read in known locations

# print(data['Label'])
pts = rink_locs[0]
for feature in key_loc_pairs.keys():
    loc = key_loc_pairs[feature]
    x,y = pts[loc]
    if x != -1 and y != -1:
        plt.scatter(x,y, label= feature)
#     print( value )
plt.imshow(mpimg.imread( os.path.join(IMAGE_DIR, image_list[0]) ))



images = [mpimg.imread(os.path.join(IMAGE_DIR, im_name)) for im_name in image_list] #[mpimg.imread(os.path.join(IMAGE_DIR, im_name)) for im_name in image_names]

# %%
for feature in key_loc_pairs.keys():
    loc = key_loc_pairs[feature]
    x,y = pts[loc]
    if x != -1 and y != -1:
        plt.scatter(x,y, label= feature)
plt.legend()
plt.imshow(mpimg.imread( os.path.join(IMAGE_DIR, image_list[0]) ))

# %%
#Create Tensorflow Datasets for Training and Validation
batchSize = 5
# seq_len = 30
outputs = (len(known_rink_locs), 2)

IMAGE_DIR = os.path.abspath("./RushPlay2/")
# print(os.listdir(IMAGE_DIR))
# images = [mpimg.imread(os.path.join(IMAGE_DIR, im)) for im in data['External ID'][:3]]

# transfer_values = inception.process_images(inception.transfer_values, images= images)
# image_data = np.array([model.transfer_values(image= image_) for image_ in images])
# transfer_values = model.process_images(transfer_values_cache(),  )
# transfer_values = model_TL.transfer_values(images= gt_im)
# tv_size = image_data.shape[-1]
tv_size = 2048
loc_len = len(known_rink_locs)

#Define variables
# x = tf.placeholder(shape=[None, seq_len, 64, 64, 3], dtype=tf.float32) 
x = tf.placeholder(shape= [None, tv_size], dtype= tf.float32)
y = tf.placeholder(shape=[None, loc_len, 2], dtype=tf.int32) 
y_in_img = tf.placeholder(shape= [None, loc_len], dtype= tf.float32)
y_float = tf.cast(y, dtype= tf.float32)

# %%
X_train_ims, X_test_ims, Y_in_image_train, Y_in_image_test, Y_train, Y_test =  train_test_split(images, y_in_image, rink_locs, test_size=0.2, random_state=42)
X_train = np.array([model.transfer_values(image= image_) for image_ in X_train_ims])
X_test = np.array([model.transfer_values(image= image_) for image_ in X_test_ims])
print(X_train.shape, X_test.shape)
# Out:
# (104, 2048) (27, 2048)

# %%
def plots(lossArrs, distArrs, valItrs, itr, save= False):
    plt.figure()
    #plt.subplot(211)
    line1 = plt.plot(range(itr), lossArrs[0], label="Train loss vals")
    # Create a legend for the first line.
    #first_legend = plt.legend( handles=[line1], loc=1 )
    #plt.subplot(212)
    plt.plot(valItrs, lossArrs[1], label="Val loss values")
    plt.title("Mean Squared Error Loss over Iterations for Validation and Training Data\n")
    plt.xlabel("Iterations")
    plt.ylabel("Loss Value")
    plt.legend(loc='upper right')
    if save:
        plt.savefig(graph_path + "Loss_v_Iteration")
    else:
        plt.show()
        
        
    plt.figure()
    #plt.subplot(275)
    plt.plot(range(itr), distArrs[0], label= "Train avg distance errors")
    plt.plot(valItrs, distArrs[1], label = "Val avg distance errors")
    plt.title("Average Distance Error over Iterations for Validation and Training Data\n")
    plt.xlabel("Iterations")
    plt.ylabel("Average Distance Value")
    plt.legend(loc='upper right')
    if save:
        plt.savefig(graph_path+"AvgDst_v_Iteration")
    else:
        plt.show()
        
#     xAxis = np.arange(0, 20.5, .5)
#     print xAxis
#     yVals = [[], [], [], [], [], [], []]
#     #print finalValPtDiff
#     #size = float(finalValPtDiff.size)
#     labels = ["head", "right shoulder", "left shoulder", "righ wrist", "left wrist", "right elbow", "left elbow"]
#     for val in xAxis:
#         for i in range(len(labels)):
#             temp = np.copy(finalValPtDiff)[:,:,i]
#             #print temp.shape
#             temp[ temp < val] = 0
#             #print temp
#             count = np.count_nonzero( temp )
#             #print count
#             yVals[i].append(1- (count/float(temp.size)))

#     plt.figure()
#     for i in range(len(labels)):
#         plt.plot(xAxis, yVals[i], label= labels[i])
#     plt.legend(loc='upper left')
#     plt.title("Accuracy Percent per Distance")
#     plt.savefig(graph_path+"Accuracy Percent per Distance")

# %%
W_out = weight_variable("output_weights", [tv_size, loc_len*2])
W_in_img = weight_variable("output_in_img_weights", [tv_size, loc_len])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-0abd28bfe99c> in <module>()
# ----> 1 W_out = weight_variable("output_weights", [tv_size, loc_len*2])
#       2 W_in_img = weight_variable("output_in_img_weights", [tv_size, loc_len])
#       3
#
# <ipython-input-5-f02305614137> in weight_variable(name, shape)
#       3     #initial = tf.truncated_normal(shape, stddev=0.1)
#       4     return tf.get_variable(name, shape=shape,
# ----> 5                             initializer=tf.contrib.layers.xavier_initializer())
#       6
#       7 def bias_variable(shape):
#
# ~/.virtualenvs/3tensorflow/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py in get_variable(name, shape, dtype, initializer, regularizer, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint)
#    1315       partitioner=partitioner, validate_shape=validate_shape,
#    1316       use_resource=use_resource, custom_getter=custom_getter,
# -> 1317       constraint=constraint)
#    1318 get_variable_or_local_docstring = (
#    1319     """%s
#
# ~/.virtualenvs/3tensorflow/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py in get_variable(self, var_store, name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint)
#    1077           partitioner=partitioner, validate_shape=validate_shape,
#    1078           use_resource=use_resource, custom_getter=custom_getter,
# -> 1079           constraint=constraint)
#    1080
#    1081   def _get_partitioned_variable(self,
#
# ~/.virtualenvs/3tensorflow/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py in get_variable(self, name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint)
#     423           caching_device=caching_device, partitioner=partitioner,
#     424           validate_shape=validate_shape, use_resource=use_resource,
# --> 425           constraint=constraint)
#     426
#     427   def _get_partitioned_variable(
#
# ~/.virtualenvs/3tensorflow/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py in _true_getter(name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, constraint)
#     392           trainable=trainable, collections=collections,
#     393           caching_device=caching_device, validate_shape=validate_shape,
# --> 394           use_resource=use_resource, constraint=constraint)
#     395
#     396     if custom_getter is not None:
#
# ~/.virtualenvs/3tensorflow/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py in _get_single_variable(self, name, shape, dtype, initializer, regularizer, partition_info, reuse, trainable, collections, caching_device, validate_shape, use_resource, constraint)
#     731                          "reuse=tf.AUTO_REUSE in VarScope? "
#     732                          "Originally defined at:\n\n%s" % (
# --> 733                              name, "".join(traceback.format_list(tb))))
#     734       found_var = self._vars[name]
#     735       if not shape.is_compatible_with(found_var.get_shape()):
#
# ValueError: Variable output_weights already exists, disallowed. Did you mean to set reuse=True or reuse=tf.AUTO_REUSE in VarScope? Originally defined at:
#
#   File "<ipython-input-5-f02305614137>", line 5, in weight_variable
#     initializer=tf.contrib.layers.xavier_initializer())
#   File "<ipython-input-17-0abd28bfe99c>", line 1, in <module>
#     W_out = weight_variable("output_weights", [tv_size, loc_len*2])
#   File "/Users/Austin_Egri/.virtualenvs/3tensorflow/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)

# %%
W_star = tf.identity(W_out)

# %%
y_hat = tf.matmul(x, W_out)
y_in_img_hat = tf.sigmoid(tf.matmul(x, W_in_img))
in_im_hat = y_in_img_hat > .5

# tf.cond(y_in_img_hat > .5, 1, 0)

y_hat = tf.reshape(y_hat, [-1, y_hat.shape[1]//2, 2])
print(y_hat)
print(y_in_img_hat)
# Out:
# Tensor("Reshape_4:0", shape=(?, 31, 2), dtype=float32)
# Tensor("Sigmoid_2:0", shape=(?, 31), dtype=float32)

# %%
# loss function
eta = 1e-6
mse_loss = tf.losses.mean_squared_error(y_float*tf.reshape(y_in_img, [-1,loc_len, 1]), y_hat*tf.reshape(y_in_img, [-1,loc_len, 1]))
mse_in_img_loss = tf.losses.mean_squared_error(y_in_img, y_in_im_hat)

alpha = 1.0
train_step = tf.train.AdamOptimizer(eta).minimize(mse_loss + alpha*mse_in_img_loss)
pointDiff = tf.norm(y_hat - y_float, axis= 2)
totDiff = tf.reduce_mean(tf.reduce_mean(pointDiff, axis= 0))

predict_op = tf.cast(y_hat, dtype= tf.int64)
pred_in_image = tf.cast(in_im_hat, dtype= tf.bool)
train_step = tf.train.AdamOptimizer(1e-4).minimize(mse_loss)
print(pointDiff.shape)
print(totDiff.shape)
print(mse_loss.shape)

##########  Declare Variables for Saving ############################## 
# Save the model
tf.get_collection('validation_nodes')

# Add opts to the collection
tf.add_to_collection('validation_nodes', x)
tf.add_to_collection('validation_nodes', y)
tf.add_to_collection('validation_nodes', predict_op)
##########  End Variable Declaration for Saving ##############################
# Out:
# (?, 31)
# ()
# ()

# %%
#########################################################
##  The Model                                          ##
#########################################################

# start training
saver = tf.train.Saver()
# Run one pass over the validation dataset.
#session.run(train_itr.initializer)
lossArrs = [[], [], []] #train, val, test
distArrs = [[], [], []] #train, val, test

minDist = [np.inf, np.inf, np.inf] #train, val, test
minLoss = [np.inf, np.inf, np.inf] #train, val, test


variableValEval = False #False for faster runtime
valEvalInterval = 300
valItrs = []
# valBatchPercent = .2
# valBatchSize = 20


sRT = time()
itr = 0
logInterval = 300
epochs = 2000
max_iterations = None #101 #200000
# keepRate = .25
accLvl = .9
batchSize = 5
save_path = "./my_model/my_model"


graph_path = "./graphs/"
#feedDictItrTrain = {xTrainPH: xTrain, yTrainPH: yTrain}

# Launch the graph in a session.
session = tf.Session()

# %%
session.run(tf.global_variables_initializer())
#train_handle = session.run(train_itr.string_handle())
#val_handle = session.run(val_itr.string_handle())
print
for i in range(epochs):
    if max_iterations != None and max_iterations <= itr:
        print("here", itr)
        break
    #if i > 0:
    #shuffle and create new batches
    X_train, X_train_ims, Y_train, Y_in_image_train = shuffle(X_train, X_train_ims, Y_train, Y_in_image_train, random_state= i)
    
    
#     X_train_batch = np.array_split(X_train, len(X_train)/batchSize)
#     Y_train_batch = np.array_split(Y_train, len(Y_train)/batchSize)

    
    
    '''
    session.run(train_itr.initializer, feed_dict= feedDictItrTrain)
    j = 0
    while True:
        #print j
        try:
            batch = session.run(next_elementTrain, feed_dict={handle: train_handle})
            #print batch[0].shape
            #print batch[1].shape
        except tf.errors.OutOfRangeError:
              break
    '''
    for j in range(len(np.ceil(X_train/batchSize))-1):
#         if max_iterations != None and max_iterations <= itr:
#             break  
        #print batch[1]
        
                #feedDict = {x: batch[0], y: batch[1], keep_prob: 0.5}
        #feedDict = {x: batch[0], y: batch[1], keep_prob: keepRate}
        if j+batchSize > len(X_train):
            X_train_batch = X_train[j:]
            Y_train_batch = Y_train[j:]
            Y_in_train_batch = Y_in_image_train[j:]
        elif j == len(X_train):
            break
        else:
            X_train_batch = X_train[j:j+batchSize]
            Y_train_batch = Y_train[j:j+batchSize]
            Y_in_train_batch = Y_in_image_train[j:j+batchSize]
        
        
        feedDict = {x: X_train_batch, y: Y_train_batch, y_in_img: Y_in_train_batch}
        trainLoss, trainDist, _ = session.run([mse_loss, totDiff, train_step], feed_dict= feedDict)
        lossArrs[0].append(trainLoss)
        distArrs[0].append(trainDist)
        if trainDist < minDist[0]:
            minDist[0] = trainDist
        if trainLoss < minLoss[0]:
            minLoss[0] = trainLoss
#         if itr%trainAccInterval == 0:
#             trainItrs.append(itr)
#             accArrs[0].append(accuracy.eval(feed_dict= feedDict))
#             if maxAcc[0] < accArrs[0][-1]:
#                 maxAcc[0] = accArrs[0][-1]
        if (itr+1)%valEvalInterval == 0:
            valItrs.append(itr)
            
#             xValBatch, _, yValBatch, _ = train_test_split(X_test, Y_test, test_size= 1-valBatchPercent, shuffle= True)
            feedDictVal = { x: X_test, y: Y_test, y_in_img: Y_in_image_test}
            
            valLoss, valDiff, valPointDiff = session.run([mse_loss, totDiff, pointDiff], feed_dict= feedDictVal)
            distArrs[1].append(valDiff)
            lossArrs[1].append(valLoss)
            if valDiff < minDist[1]:
                minDist[1] = valDiff
                #test accuracy is a new maximum.  Save the graph
                # this saver.save() should be within the same tf.Session() after the training is done
                #Only save if greater than a threshold... that way we don't waste time
#                 if variableValEval:
#                     if minAcc[1] > accLvl:
#                         saver.save(session, save_path)
#                         valEvalInterval = max(1, round(np.sqrt(valEvalInterval)))
#                     elif minAcc[1] < .8*accLvl:
#                         valEvalInterval = max(50, round(np.sqrt(valEvalInterval)))
#                     else:
#                         valEvalInterval = max(5, round(np.sqrt(valEvalInterval)))
#                 else:
#                     saver.save(session, save_path)
            if valLoss < minLoss[1]:
                minLoss[1] = valLoss
            
                # save the weights
                W_star_ = session.run(W_star)
                
        if (itr+1)%logInterval == 0:
            #dataset = dataset.shuffle(buffer_size=10000)
            #feedDict= { x:batch[0], y: batch[1], keep_prob: 1.0}
            
            feedDict= { x: X_train_batch, y: Y_train_batch, y_in_img: Y_in_train_batch}
            trainLoss, trainDiff, trainPtDiff = session.run([mse_loss, totDiff, pointDiff], feed_dict= feedDict)
            if (itr+1)%valEvalInterval != 0:
                #session.run(val_itr.initializer)
                #dVal = session.run(next_elementVal, feed_dict= {handle: val_handle})
                #feedDictVal = { x: dVal[:len(dVal)/2][0], y: dVal[len(dVal)/2:][0], keep_prob: 1.0}
#                 xValBatch, _, yValBatch, _ = train_test_split(xVal, yVal, test_size= 1-valBatchPercent, shuffle= True)
                feedDictVal = { x: X_test, y: Y_test}
                valLoss, valDist, valPointDist = session.run( [mse_loss, totDiff, pointDiff], feedDictVal)
            print("Epoch %d, step %d,     training dist: %g"%(i, j, trainDiff))
            print("                            val dist: %g"%(valDiff))
            print("                      training loss: %g"%(trainLoss))
            print("                     validation loss: %g"%(valLoss))
            print("                  min validation dist: %g"%(minDist[1]))
            print("                       min train dist: %g"%(minDist[0]))
#             plots(lossArrs, distArrs, valItrs, itr+1, save= False)
            print("                                 RT = %.2f"%(time()-sRT))
            sys.stdout.flush()
        itr +=1   
plots(lossArrs, distArrs, valItrs, itr, save= False)
# Out:
# Epoch 0, step 99,     training dist: 298.885
#                             val dist: 293.245
#                       training loss: 11850.5
#                      validation loss: 79282.8
#                   min validation dist: 293.245
#                        min train dist: 237.994
#                                  RT = 253.55
# Epoch 1, step 96,     training dist: 317.984
#                             val dist: 293.73
#                       training loss: 36573.3
#                      validation loss: 78752.2
#                   min validation dist: 293.245
#                        min train dist: 237.616
#                                  RT = 253.77
# Epoch 2, step 93,     training dist: 320.438
#                             val dist: 294.046
#                       training loss: 7294.17
#                      validation loss: 78311.8
#                   min validation dist: 293.245
#                        min train dist: 234.608
#                                  RT = 254.00
# Epoch 3, step 90,     training dist: 325.38
#                             val dist: 294.672
#                       training loss: 53275.9
#                      validation loss: 77799.1
#                   min validation dist: 293.245
#                        min train dist: 230.266
#                                  RT = 254.18
# Epoch 4, step 87,     training dist: 289.55
#                             val dist: 295.032
#                       training loss: 36588.7
#                      validation loss: 77326.3
#                   min validation dist: 293.245
#                        min train dist: 230.266
#                                  RT = 254.40
# Epoch 5, step 84,     training dist: 302.005
#                             val dist: 295.807
#                       training loss: 7481.96
#                      validation loss: 76717.6
#                   min validation dist: 293.245
#                        min train dist: 230.266
#                                  RT = 254.66
# Epoch 6, step 81,     training dist: 365.45
#                             val dist: 296.061
#                       training loss: 33721.2
#                      validation loss: 76311.8
#                   min validation dist: 293.245
#                        min train dist: 230.266
#                                  RT = 254.88
# Epoch 7, step 78,     training dist: 332.16
#                             val dist: 296.542
#                       training loss: 39084.8
#                      validation loss: 75848.8
#                   min validation dist: 293.245
#                        min train dist: 230.266
#                                  RT = 255.07
# Epoch 8, step 75,     training dist: 322.26
#                             val dist: 296.813
#                       training loss: 57441.1
#                      validation loss: 75466.7
#                   min validation dist: 293.245
#                        min train dist: 230.266
#                                  RT = 255.23
# Epoch 9, step 72,     training dist: 297.502
#                             val dist: 297.122
#                       training loss: 13197.3
#                      validation loss: 75037.6
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 255.41
# Epoch 10, step 69,     training dist: 336.695
#                             val dist: 297.418
#                       training loss: 38504.3
#                      validation loss: 74680.7
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 255.62
# Epoch 11, step 66,     training dist: 279.614
#                             val dist: 297.977
#                       training loss: 30328
#                      validation loss: 74159.3
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 255.78
# Epoch 12, step 63,     training dist: 305.955
#                             val dist: 298.228
#                       training loss: 61744.1
#                      validation loss: 73791.4
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 255.93
# Epoch 13, step 60,     training dist: 301.464
#                             val dist: 299.145
#                       training loss: 46472.3
#                      validation loss: 73210.2
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 256.30
# Epoch 14, step 57,     training dist: 331.143
#                             val dist: 299.107
#                       training loss: 20777.8
#                      validation loss: 72962.2
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 256.67
# Epoch 15, step 54,     training dist: 280.171
#                             val dist: 299.64
#                       training loss: 19298.6
#                      validation loss: 72492.7
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 256.96
# Epoch 16, step 51,     training dist: 349.337
#                             val dist: 299.874
#                       training loss: 53127.6
#                      validation loss: 72147.4
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 257.31
# Epoch 17, step 48,     training dist: 280.146
#                             val dist: 300.322
#                       training loss: 6344.12
#                      validation loss: 71749.5
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 257.55
# Epoch 18, step 45,     training dist: 292.856
#                             val dist: 300.705
#                       training loss: 4944.02
#                      validation loss: 71303.9
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 257.80
# Epoch 19, step 42,     training dist: 283.011
#                             val dist: 301.088
#                       training loss: 30615.9
#                      validation loss: 70925.1
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 257.97
# Epoch 20, step 39,     training dist: 333.759
#                             val dist: 301.412
#                       training loss: 47929.6
#                      validation loss: 70578.6
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 258.12
# Epoch 21, step 36,     training dist: 338.45
#                             val dist: 301.858
#                       training loss: 45636.7
#                      validation loss: 70201.6
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 258.28
# Epoch 22, step 33,     training dist: 272.094
#                             val dist: 301.705
#                       training loss: 30442.1
#                      validation loss: 70042.7
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 258.44
# Epoch 23, step 30,     training dist: 311.052
#                             val dist: 302.211
#                       training loss: 30343.7
#                      validation loss: 69590.1
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 258.63
# Epoch 24, step 27,     training dist: 345.862
#                             val dist: 302.536
#                       training loss: 49165.4
#                      validation loss: 69257.5
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 258.82
# Epoch 25, step 24,     training dist: 317.756
#                             val dist: 302.647
#                       training loss: 48238
#                      validation loss: 69015.1
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 258.98
# Epoch 26, step 21,     training dist: 309.143
#                             val dist: 302.956
#                       training loss: 9491.32
#                      validation loss: 68693.4
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 259.13
# Epoch 27, step 18,     training dist: 291.212
#                             val dist: 303.399
#                       training loss: 39863.8
#                      validation loss: 68274.9
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 259.30
# Epoch 28, step 15,     training dist: 331.387
#                             val dist: 303.601
#                       training loss: 42439.5
#                      validation loss: 68000
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 259.45
# Epoch 29, step 12,     training dist: 294.356
#                             val dist: 303.923
#                       training loss: 11807.1
#                      validation loss: 67663.6
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 259.65
# Epoch 30, step 9,     training dist: 290.589
#                             val dist: 304.178
#                       training loss: 27758.7
#                      validation loss: 67377.1
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 259.95
# Epoch 31, step 6,     training dist: 308.693
#                             val dist: 304.347
#                       training loss: 22199.3
#                      validation loss: 67111
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 260.22
# Epoch 32, step 3,     training dist: 341.471
#                             val dist: 304.564
#                       training loss: 70982.8
#                      validation loss: 66812.4
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 260.42
# Epoch 33, step 0,     training dist: 327.547
#                             val dist: 304.734
#                       training loss: 65719.1
#                      validation loss: 66556.6
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 260.61
# Epoch 33, step 100,     training dist: 330.248
#                             val dist: 305.047
#                       training loss: 10468.2
#                      validation loss: 66226.9
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 260.79
# Epoch 34, step 97,     training dist: 302.853
#                             val dist: 305.061
#                       training loss: 44162
#                      validation loss: 66071.3
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 261.01
# Epoch 35, step 94,     training dist: 331.071
#                             val dist: 305.518
#                       training loss: 27761
#                      validation loss: 65705.1
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 261.19
# Epoch 36, step 91,     training dist: 329.817
#                             val dist: 305.701
#                       training loss: 35353.8
#                      validation loss: 65452.9
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 261.37
# Epoch 37, step 88,     training dist: 279.861
#                             val dist: 305.776
#                       training loss: 11841
#                      validation loss: 65249.4
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 261.58
# Epoch 38, step 85,     training dist: 334.874
#                             val dist: 306.138
#                       training loss: 34953.2
#                      validation loss: 64915.1
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 261.75
# Epoch 39, step 82,     training dist: 321.334
#                             val dist: 306.434
#                       training loss: 8332.58
#                      validation loss: 64600.9
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 261.93
# Epoch 40, step 79,     training dist: 314.258
#                             val dist: 306.341
#                       training loss: 24906.1
#                      validation loss: 64519.1
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 262.10
# Epoch 41, step 76,     training dist: 304.162
#                             val dist: 306.542
#                       training loss: 35471
#                      validation loss: 64258.1
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 262.28
# Epoch 42, step 73,     training dist: 296.449
#                             val dist: 306.839
#                       training loss: 24783.8
#                      validation loss: 63979.1
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 262.45
# Epoch 43, step 70,     training dist: 318.981
#                             val dist: 307.07
#                       training loss: 33488.9
#                      validation loss: 63737.8
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 262.63
# Epoch 44, step 67,     training dist: 288.701
#                             val dist: 307.381
#                       training loss: 20641.6
#                      validation loss: 63452.9
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 262.81
# Epoch 45, step 64,     training dist: 312.062
#                             val dist: 307.388
#                       training loss: 31534.1
#                      validation loss: 63303
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 262.98
# Epoch 46, step 61,     training dist: 327.207
#                             val dist: 307.701
#                       training loss: 38174.7
#                      validation loss: 63013.1
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 263.18
# Epoch 47, step 58,     training dist: 292.803
#                             val dist: 307.964
#                       training loss: 16754
#                      validation loss: 62746.5
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 263.38
# Epoch 48, step 55,     training dist: 339.418
#                             val dist: 308.179
#                       training loss: 33139.2
#                      validation loss: 62550.3
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 263.57
# Epoch 49, step 52,     training dist: 328.097
#                             val dist: 308.101
#                       training loss: 9484.97
#                      validation loss: 62413.9
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 263.75
# Epoch 50, step 49,     training dist: 279.598
#                             val dist: 308.341
#                       training loss: 6856.87
#                      validation loss: 62183.9
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 263.99
# Epoch 51, step 46,     training dist: 301.132
#                             val dist: 308.824
#                       training loss: 24437.4
#                      validation loss: 61831.6
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 264.18
# Epoch 52, step 43,     training dist: 317.892
#                             val dist: 308.843
#                       training loss: 27789.3
#                      validation loss: 61721.4
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 264.34
# Epoch 53, step 40,     training dist: 304.098
#                             val dist: 308.999
#                       training loss: 6466.42
#                      validation loss: 61516.4
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 264.50
# Epoch 54, step 37,     training dist: 290.138
#                             val dist: 309.036
#                       training loss: 30418.2
#                      validation loss: 61405.6
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 264.78
# Epoch 55, step 34,     training dist: 342.374
#                             val dist: 309.148
#                       training loss: 11730.2
#                      validation loss: 61237
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 264.95
# Epoch 56, step 31,     training dist: 297.833
#                             val dist: 309.306
#                       training loss: 31751.1
#                      validation loss: 61023.5
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 265.14
# Epoch 57, step 28,     training dist: 316.053
#                             val dist: 309.531
#                       training loss: 15082.6
#                      validation loss: 60813.2
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 265.34
# Epoch 58, step 25,     training dist: 325.247
#                             val dist: 309.694
#                       training loss: 19868.4
#                      validation loss: 60640.6
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 265.58
# Epoch 59, step 22,     training dist: 331.667
#                             val dist: 309.696
#                       training loss: 12862
#                      validation loss: 60510.6
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 265.75
# Epoch 60, step 19,     training dist: 325.885
#                             val dist: 309.948
#                       training loss: 22689.7
#                      validation loss: 60297.4
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 265.92
# Epoch 61, step 16,     training dist: 309.891
#                             val dist: 310.218
#                       training loss: 29916.5
#                      validation loss: 60088.7
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 266.21
# Epoch 62, step 13,     training dist: 304.523
#                             val dist: 310.301
#                       training loss: 29187.2
#                      validation loss: 59923.5
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 266.59
# Epoch 63, step 10,     training dist: 312.506
#                             val dist: 310.529
#                       training loss: 29247
#                      validation loss: 59728.7
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 266.89
# Epoch 64, step 7,     training dist: 321.993
#                             val dist: 310.577
#                       training loss: 11522.5
#                      validation loss: 59601.1
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 267.14
# Epoch 65, step 4,     training dist: 315.464
#                             val dist: 310.771
#                       training loss: 25830.4
#                      validation loss: 59395
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 267.35
# Epoch 66, step 1,     training dist: 330.829
#                             val dist: 311.072
#                       training loss: 42676.1
#                      validation loss: 59163
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 267.51
# Epoch 66, step 101,     training dist: 306.75
#                             val dist: 311.01
#                       training loss: 38318.5
#                      validation loss: 59084.5
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 267.68
# Epoch 67, step 98,     training dist: 324.808
#                             val dist: 311.317
#                       training loss: 11747
#                      validation loss: 58855.5
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 267.89
# Epoch 68, step 95,     training dist: 322.767
#                             val dist: 311.242
#                       training loss: 45754.9
#                      validation loss: 58802.5
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 268.09
# Epoch 69, step 92,     training dist: 309.047
#                             val dist: 311.507
#                       training loss: 29921.8
#                      validation loss: 58582.7
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 268.26
# Epoch 70, step 89,     training dist: 272.523
#                             val dist: 311.787
#                       training loss: 10821.3
#                      validation loss: 58356.5
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 268.43
# Epoch 71, step 86,     training dist: 332.552
#                             val dist: 311.662
#                       training loss: 26763.1
#                      validation loss: 58313.6
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 268.60
# Epoch 72, step 83,     training dist: 287.631
#                             val dist: 311.774
#                       training loss: 17536.6
#                      validation loss: 58137.3
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 268.91
# Epoch 73, step 80,     training dist: 317.237
#                             val dist: 311.858
#                       training loss: 26095.4
#                      validation loss: 58005.6
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 269.24
# Epoch 74, step 77,     training dist: 307.986
#                             val dist: 312.106
#                       training loss: 19780.9
#                      validation loss: 57804.6
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 269.54
# Epoch 75, step 74,     training dist: 333.026
#                             val dist: 311.984
#                       training loss: 63534.2
#                      validation loss: 57769.7
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 269.77
# Epoch 76, step 71,     training dist: 299.882
#                             val dist: 312.401
#                       training loss: 21182.6
#                      validation loss: 57445.9
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 269.93
# Epoch 77, step 68,     training dist: 311.889
#                             val dist: 312.243
#                       training loss: 25216.5
#                      validation loss: 57493
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 270.11
# Epoch 78, step 65,     training dist: 346.217
#                             val dist: 312.385
#                       training loss: 27702.9
#                      validation loss: 57291.3
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 270.43
# Epoch 79, step 62,     training dist: 318.543
#                             val dist: 312.507
#                       training loss: 24588.2
#                      validation loss: 57167.1
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 270.60
# Epoch 80, step 59,     training dist: 349.46
#                             val dist: 312.656
#                       training loss: 40160.8
#                      validation loss: 56972.8
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 270.85
# Epoch 81, step 56,     training dist: 326.682
#                             val dist: 312.73
#                       training loss: 42716.4
#                      validation loss: 56900.1
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 271.14
# Epoch 82, step 53,     training dist: 292.793
#                             val dist: 312.511
#                       training loss: 19418.3
#                      validation loss: 56873.5
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 271.31
# Epoch 83, step 50,     training dist: 295.172
#                             val dist: 312.859
#                       training loss: 28961.9
#                      validation loss: 56610.6
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 271.48
# Epoch 84, step 47,     training dist: 312.532
#                             val dist: 312.738
#                       training loss: 37381.2
#                      validation loss: 56527
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 271.65
# Epoch 85, step 44,     training dist: 327.656
#                             val dist: 313.048
#                       training loss: 22257.6
#                      validation loss: 56306.9
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 271.86
# Epoch 86, step 41,     training dist: 296.409
#                             val dist: 312.97
#                       training loss: 12241.7
#                      validation loss: 56283.6
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 272.03
# Epoch 87, step 38,     training dist: 317.608
#                             val dist: 313.128
#                       training loss: 24220.8
#                      validation loss: 56096.5
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 272.20
# Epoch 88, step 35,     training dist: 313.926
#                             val dist: 313.139
#                       training loss: 23335.8
#                      validation loss: 56020.3
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 272.37
# Epoch 89, step 32,     training dist: 347.776
#                             val dist: 312.995
#                       training loss: 56627.2
#                      validation loss: 55966.4
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 272.55
# Epoch 90, step 29,     training dist: 300.548
#                             val dist: 313.249
#                       training loss: 16996.7
#                      validation loss: 55787.8
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 272.71
# Epoch 91, step 26,     training dist: 341.313
#                             val dist: 313.138
#                       training loss: 44364
#                      validation loss: 55743.2
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 272.89
# Epoch 92, step 23,     training dist: 329.29
#                             val dist: 313.52
#                       training loss: 35590.8
#                      validation loss: 55500.9
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 273.22
# Epoch 93, step 20,     training dist: 345.195
#                             val dist: 313.358
#                       training loss: 11583.6
#                      validation loss: 55449.6
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 273.58
# Epoch 94, step 17,     training dist: 321.191
#                             val dist: 313.402
#                       training loss: 18108.8
#                      validation loss: 55330
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 273.92
# Epoch 95, step 14,     training dist: 292.578
#                             val dist: 313.387
#                       training loss: 10001.1
#                      validation loss: 55261
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 274.23
# Epoch 96, step 11,     training dist: 331.477
#                             val dist: 313.415
#                       training loss: 27258.4
#                      validation loss: 55154.1
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 274.45
# Epoch 97, step 8,     training dist: 292.357
#                             val dist: 313.459
#                       training loss: 39353.8
#                      validation loss: 55056.6
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 274.63
# Epoch 98, step 5,     training dist: 352.051
#                             val dist: 313.621
#                       training loss: 27913
#                      validation loss: 54890.6
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 274.80
# Epoch 99, step 2,     training dist: 308.967
#                             val dist: 313.592
#                       training loss: 17380.1
#                      validation loss: 54804.6
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 275.13
# Epoch 99, step 102,     training dist: 319.59
#                             val dist: 313.569
#                       training loss: 48718.5
#                      validation loss: 54711.4
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 275.42
# Epoch 100, step 99,     training dist: 290.516
#                             val dist: 313.586
#                       training loss: 31260
#                      validation loss: 54624.1
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 275.70
# Epoch 101, step 96,     training dist: 336.434
#                             val dist: 313.736
#                       training loss: 29096.2
#                      validation loss: 54462.2
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 275.88
# Epoch 102, step 93,     training dist: 322.997
#                             val dist: 313.75
#                       training loss: 26478.5
#                      validation loss: 54373.7
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 276.03
# Epoch 103, step 90,     training dist: 321.482
#                             val dist: 313.677
#                       training loss: 43392.6
#                      validation loss: 54302.4
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 276.18
# Epoch 104, step 87,     training dist: 314.701
#                             val dist: 313.895
#                       training loss: 7015.24
#                      validation loss: 54101
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 276.33
# Epoch 105, step 84,     training dist: 326.159
#                             val dist: 313.709
#                       training loss: 18854.8
#                      validation loss: 54091.9
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 276.49
# Epoch 106, step 81,     training dist: 306.912
#                             val dist: 313.94
#                       training loss: 29224.4
#                      validation loss: 53904.4
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 276.64
# Epoch 107, step 78,     training dist: 299.324
#                             val dist: 313.971
#                       training loss: 12916.8
#                      validation loss: 53789.4
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 276.77
# Epoch 108, step 75,     training dist: 313.534
#                             val dist: 313.96
#                       training loss: 14229
#                      validation loss: 53709.5
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 276.91
# Epoch 109, step 72,     training dist: 317.035
#                             val dist: 313.961
#                       training loss: 8432.33
#                      validation loss: 53676.1
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 277.05
# Epoch 110, step 69,     training dist: 340.882
#                             val dist: 313.732
#                       training loss: 29941.8
#                      validation loss: 53644.4
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 277.19
# Epoch 111, step 66,     training dist: 300.843
#                             val dist: 313.956
#                       training loss: 8659.82
#                      validation loss: 53440.7
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 277.32
# Epoch 112, step 63,     training dist: 302.585
#                             val dist: 313.844
#                       training loss: 20366
#                      validation loss: 53443.1
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 277.46
# Epoch 113, step 60,     training dist: 314.634
#                             val dist: 313.961
#                       training loss: 29760
#                      validation loss: 53307.7
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 277.60
# Epoch 114, step 57,     training dist: 351.173
#                             val dist: 313.712
#                       training loss: 16746.7
#                      validation loss: 53274.5
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 277.73
# Epoch 115, step 54,     training dist: 293.253
#                             val dist: 313.576
#                       training loss: 12293.2
#                      validation loss: 53242.1
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 277.87
# Epoch 116, step 51,     training dist: 334.515
#                             val dist: 313.438
#                       training loss: 28991.4
#                      validation loss: 53207.5
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 278.01
# Epoch 117, step 48,     training dist: 329.429
#                             val dist: 313.415
#                       training loss: 31761.9
#                      validation loss: 53102
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 278.14
# Epoch 118, step 45,     training dist: 313.784
#                             val dist: 313.518
#                       training loss: 9078.41
#                      validation loss: 52982.7
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 278.38
# Epoch 119, step 42,     training dist: 329.235
#                             val dist: 313.551
#                       training loss: 8167.4
#                      validation loss: 52872.2
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 278.63
# Epoch 120, step 39,     training dist: 303.323
#                             val dist: 313.36
#                       training loss: 30194.1
#                      validation loss: 52851.6
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 278.88
# Epoch 121, step 36,     training dist: 302.692
#                             val dist: 313.304
#                       training loss: 13689.2
#                      validation loss: 52819.1
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 279.12
# Epoch 122, step 33,     training dist: 316.301
#                             val dist: 313.319
#                       training loss: 28687.4
#                      validation loss: 52668.9
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 279.37
# Epoch 123, step 30,     training dist: 332.499
#                             val dist: 313.422
#                       training loss: 29296.3
#                      validation loss: 52562.3
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 279.62
# Epoch 124, step 27,     training dist: 302.906
#                             val dist: 313.352
#                       training loss: 28075.9
#                      validation loss: 52522.7
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 279.88
# Epoch 125, step 24,     training dist: 332.561
#                             val dist: 313.228
#                       training loss: 36022.2
#                      validation loss: 52481.9
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 280.17
# Epoch 126, step 21,     training dist: 331.098
#                             val dist: 313.311
#                       training loss: 13281
#                      validation loss: 52354.5
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 280.36
# Epoch 127, step 18,     training dist: 292.598
#                             val dist: 313.174
#                       training loss: 12538
#                      validation loss: 52307.4
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 280.52
# Epoch 128, step 15,     training dist: 321.911
#                             val dist: 313.26
#                       training loss: 27988.7
#                      validation loss: 52195.1
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 280.66
# Epoch 129, step 12,     training dist: 316.516
#                             val dist: 313.084
#                       training loss: 28646.3
#                      validation loss: 52196.3
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 280.83
# Epoch 130, step 9,     training dist: 297.434
#                             val dist: 313.155
#                       training loss: 11630.2
#                      validation loss: 52063.3
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 280.99
# Epoch 131, step 6,     training dist: 293.148
#                             val dist: 313.103
#                       training loss: 9167
#                      validation loss: 51993.1
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 281.13
# Epoch 132, step 3,     training dist: 289.547
#                             val dist: 312.986
#                       training loss: 11039
#                      validation loss: 51972.3
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 281.27
# Epoch 133, step 0,     training dist: 323.493
#                             val dist: 313.039
#                       training loss: 9283.75
#                      validation loss: 51857.6
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 281.41
# Epoch 133, step 100,     training dist: 339.652
#                             val dist: 313.153
#                       training loss: 30433.1
#                      validation loss: 51727
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 281.55
# Epoch 134, step 97,     training dist: 303.15
#                             val dist: 313.139
#                       training loss: 15283.4
#                      validation loss: 51642.9
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 281.68
# Epoch 135, step 94,     training dist: 305.582
#                             val dist: 312.907
#                       training loss: 28491.4
#                      validation loss: 51673.3
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 281.82
# Epoch 136, step 91,     training dist: 299.574
#                             val dist: 312.926
#                       training loss: 21922.7
#                      validation loss: 51561.4
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 281.96
# Epoch 137, step 88,     training dist: 319.746
#                             val dist: 312.867
#                       training loss: 32957.6
#                      validation loss: 51485.8
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 282.10
# Epoch 138, step 85,     training dist: 304.697
#                             val dist: 312.894
#                       training loss: 22269.4
#                      validation loss: 51412.8
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 282.23
# Epoch 139, step 82,     training dist: 289.032
#                             val dist: 312.653
#                       training loss: 32587
#                      validation loss: 51403.3
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 282.37
# Epoch 140, step 79,     training dist: 309.109
#                             val dist: 312.841
#                       training loss: 13226.4
#                      validation loss: 51249.8
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 282.51
# Epoch 141, step 76,     training dist: 319.089
#                             val dist: 312.6
#                       training loss: 14736.9
#                      validation loss: 51262.5
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 282.65
# Epoch 142, step 73,     training dist: 295.398
#                             val dist: 312.587
#                       training loss: 15611.8
#                      validation loss: 51172.1
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 282.79
# Epoch 143, step 70,     training dist: 308.738
#                             val dist: 312.486
#                       training loss: 18859
#                      validation loss: 51128.9
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 282.92
# Epoch 144, step 67,     training dist: 309.647
#                             val dist: 312.289
#                       training loss: 17837.9
#                      validation loss: 51157
#                   min validation dist: 293.245
#                        min train dist: 223.325
#                                  RT = 283.06
# Epoch 145, step 64,     training dist: 310.989
#                             val dist: 312.375
# ...
#                   min validation dist: 198.421
#                        min train dist: 95.5203
#                                  RT = 616.63
# Epoch 1953, step 40,     training dist: 231.487
#                             val dist: 198.512
#                       training loss: 2894.14
#                      validation loss: 17683.7
#                   min validation dist: 198.421
#                        min train dist: 95.5203
#                                  RT = 616.80
# Epoch 1954, step 37,     training dist: 184.345
#                             val dist: 198.403
#                       training loss: 6197.82
#                      validation loss: 17721.6
#                   min validation dist: 198.403
#                        min train dist: 95.5203
#                                  RT = 616.97
# Epoch 1955, step 34,     training dist: 212.457
#                             val dist: 198.353
#                       training loss: 6929.53
#                      validation loss: 17717.4
#                   min validation dist: 198.353
#                        min train dist: 95.5203
#                                  RT = 617.13
# Epoch 1956, step 31,     training dist: 194.445
#                             val dist: 198.224
#                       training loss: 4613.75
#                      validation loss: 17731.7
#                   min validation dist: 198.224
#                        min train dist: 95.5203
#                                  RT = 617.30
# Epoch 1957, step 28,     training dist: 206.584
#                             val dist: 198.251
#                       training loss: 6066.67
#                      validation loss: 17721.5
#                   min validation dist: 198.224
#                        min train dist: 95.5203
#                                  RT = 617.49
# Epoch 1958, step 25,     training dist: 184.619
#                             val dist: 198.207
#                       training loss: 4982.71
#                      validation loss: 17707.1
#                   min validation dist: 198.207
#                        min train dist: 95.5203
#                                  RT = 617.67
# Epoch 1959, step 22,     training dist: 216.736
#                             val dist: 198.192
#                       training loss: 1991.34
#                      validation loss: 17706
#                   min validation dist: 198.192
#                        min train dist: 95.5203
#                                  RT = 617.84
# Epoch 1960, step 19,     training dist: 155.991
#                             val dist: 198.158
#                       training loss: 1955.29
#                      validation loss: 17699.3
#                   min validation dist: 198.158
#                        min train dist: 95.5203
#                                  RT = 618.01
# Epoch 1961, step 16,     training dist: 202.53
#                             val dist: 198.169
#                       training loss: 4488.55
#                      validation loss: 17689
#                   min validation dist: 198.158
#                        min train dist: 95.5203
#                                  RT = 618.18
# Epoch 1962, step 13,     training dist: 176.158
#                             val dist: 198.116
#                       training loss: 1437.98
#                      validation loss: 17691.8
#                   min validation dist: 198.116
#                        min train dist: 95.5203
#                                  RT = 618.35
# Epoch 1963, step 10,     training dist: 135.777
#                             val dist: 198.128
#                       training loss: 2829.44
#                      validation loss: 17682.6
#                   min validation dist: 198.116
#                        min train dist: 95.5203
#                                  RT = 618.54
# Epoch 1964, step 7,     training dist: 203.83
#                             val dist: 198.045
#                       training loss: 2628.88
#                      validation loss: 17689.1
#                   min validation dist: 198.045
#                        min train dist: 95.5203
#                                  RT = 618.71
# Epoch 1965, step 4,     training dist: 157.564
#                             val dist: 198.031
#                       training loss: 2467.23
#                      validation loss: 17677.6
#                   min validation dist: 198.031
#                        min train dist: 95.5203
#                                  RT = 618.88
# Epoch 1966, step 1,     training dist: 187.874
#                             val dist: 198.029
#                       training loss: 773.966
#                      validation loss: 17662.6
#                   min validation dist: 198.029
#                        min train dist: 95.5203
#                                  RT = 619.05
# Epoch 1966, step 101,     training dist: 178.096
#                             val dist: 198.015
#                       training loss: 4317.33
#                      validation loss: 17654.6
#                   min validation dist: 198.015
#                        min train dist: 95.5203
#                                  RT = 619.20
# Epoch 1967, step 98,     training dist: 201.31
#                             val dist: 198.018
#                       training loss: 3642.06
#                      validation loss: 17637.1
#                   min validation dist: 198.015
#                        min train dist: 95.5203
#                                  RT = 619.35
# Epoch 1968, step 95,     training dist: 226.533
#                             val dist: 197.951
#                       training loss: 7080.96
#                      validation loss: 17647.8
#                   min validation dist: 197.951
#                        min train dist: 95.5203
#                                  RT = 619.51
# Epoch 1969, step 92,     training dist: 195.113
#                             val dist: 197.893
#                       training loss: 6690.07
#                      validation loss: 17656.2
#                   min validation dist: 197.893
#                        min train dist: 95.5203
#                                  RT = 619.67
# Epoch 1970, step 89,     training dist: 212.511
#                             val dist: 197.896
#                       training loss: 3728.45
#                      validation loss: 17638.7
#                   min validation dist: 197.893
#                        min train dist: 95.5203
#                                  RT = 619.81
# Epoch 1971, step 86,     training dist: 214.635
#                             val dist: 197.989
#                       training loss: 892.703
#                      validation loss: 17607.9
#                   min validation dist: 197.893
#                        min train dist: 95.5203
#                                  RT = 619.97
# Epoch 1972, step 83,     training dist: 169.143
#                             val dist: 197.882
#                       training loss: 2991.67
#                      validation loss: 17622.8
#                   min validation dist: 197.882
#                        min train dist: 95.5203
#                                  RT = 620.14
# Epoch 1973, step 80,     training dist: 169.919
#                             val dist: 197.868
#                       training loss: 3926.97
#                      validation loss: 17617.7
#                   min validation dist: 197.868
#                        min train dist: 95.5203
#                                  RT = 620.29
# Epoch 1974, step 77,     training dist: 157.333
#                             val dist: 197.694
#                       training loss: 4058.88
#                      validation loss: 17663.7
#                   min validation dist: 197.694
#                        min train dist: 95.5203
#                                  RT = 620.48
# Epoch 1975, step 74,     training dist: 152.904
#                             val dist: 197.786
#                       training loss: 743.086
#                      validation loss: 17595.2
#                   min validation dist: 197.694
#                        min train dist: 95.5203
#                                  RT = 620.66
# Epoch 1976, step 71,     training dist: 166.416
#                             val dist: 197.73
#                       training loss: 4095.17
#                      validation loss: 17620.5
#                   min validation dist: 197.694
#                        min train dist: 95.5203
#                                  RT = 620.82
# Epoch 1977, step 68,     training dist: 215.221
#                             val dist: 197.818
#                       training loss: 7158.72
#                      validation loss: 17586.9
#                   min validation dist: 197.694
#                        min train dist: 95.5203
#                                  RT = 620.99
# Epoch 1978, step 65,     training dist: 198.186
#                             val dist: 197.728
#                       training loss: 3781.37
#                      validation loss: 17601.3
#                   min validation dist: 197.694
#                        min train dist: 95.5203
#                                  RT = 621.15
# Epoch 1979, step 62,     training dist: 123.725
#                             val dist: 197.77
#                       training loss: 1806.21
#                      validation loss: 17582.5
#                   min validation dist: 197.694
#                        min train dist: 95.5203
#                                  RT = 621.33
# Epoch 1980, step 59,     training dist: 212.261
#                             val dist: 197.719
#                       training loss: 2991.49
#                      validation loss: 17576.6
#                   min validation dist: 197.694
#                        min train dist: 95.5203
#                                  RT = 621.49
# Epoch 1981, step 56,     training dist: 211.221
#                             val dist: 197.664
#                       training loss: 6874.55
#                      validation loss: 17577.7
#                   min validation dist: 197.664
#                        min train dist: 95.5203
#                                  RT = 621.66
# Epoch 1982, step 53,     training dist: 203.482
#                             val dist: 197.643
#                       training loss: 1131.37
#                      validation loss: 17578.6
#                   min validation dist: 197.643
#                        min train dist: 95.5203
#                                  RT = 621.83
# Epoch 1983, step 50,     training dist: 221.171
#                             val dist: 197.598
#                       training loss: 9251.37
#                      validation loss: 17588.2
#                   min validation dist: 197.598
#                        min train dist: 95.5203
#                                  RT = 621.99
# Epoch 1984, step 47,     training dist: 208.89
#                             val dist: 197.547
#                       training loss: 4084.51
#                      validation loss: 17571.2
#                   min validation dist: 197.547
#                        min train dist: 95.5203
#                                  RT = 622.16
# Epoch 1985, step 44,     training dist: 175.207
#                             val dist: 197.578
#                       training loss: 3781.42
#                      validation loss: 17553.9
#                   min validation dist: 197.547
#                        min train dist: 95.5203
#                                  RT = 622.32
# Epoch 1986, step 41,     training dist: 169.741
#                             val dist: 197.553
#                       training loss: 3411.61
#                      validation loss: 17558.9
#                   min validation dist: 197.547
#                        min train dist: 95.5203
#                                  RT = 622.52
# Epoch 1987, step 38,     training dist: 219.263
#                             val dist: 197.457
#                       training loss: 4516.29
#                      validation loss: 17568.8
#                   min validation dist: 197.457
#                        min train dist: 95.5203
#                                  RT = 622.69
# Epoch 1988, step 35,     training dist: 175.044
#                             val dist: 197.361
#                       training loss: 2541.52
#                      validation loss: 17583.2
#                   min validation dist: 197.361
#                        min train dist: 95.5203
#                                  RT = 622.86
# Epoch 1989, step 32,     training dist: 189.817
#                             val dist: 197.519
#                       training loss: 3416.1
#                      validation loss: 17502.1
#                   min validation dist: 197.361
#                        min train dist: 95.5203
#                                  RT = 623.03
# Epoch 1990, step 29,     training dist: 225.866
#                             val dist: 197.352
#                       training loss: 6064.47
#                      validation loss: 17553.7
#                   min validation dist: 197.352
#                        min train dist: 95.5203
#                                  RT = 623.18
# Epoch 1991, step 26,     training dist: 188.528
#                             val dist: 197.401
#                       training loss: 4678.59
#                      validation loss: 17543.4
#                   min validation dist: 197.352
#                        min train dist: 95.5203
#                                  RT = 623.35
# Epoch 1992, step 23,     training dist: 173.136
#                             val dist: 197.363
#                       training loss: 4790.11
#                      validation loss: 17533.3
#                   min validation dist: 197.352
#                        min train dist: 95.5203
#                                  RT = 623.53
# Epoch 1993, step 20,     training dist: 209.033
#                             val dist: 197.344
#                       training loss: 1860.95
#                      validation loss: 17537.2
#                   min validation dist: 197.344
#                        min train dist: 95.5203
#                                  RT = 623.70
# Epoch 1994, step 17,     training dist: 161.464
#                             val dist: 197.336
#                       training loss: 4194.5
#                      validation loss: 17523.2
#                   min validation dist: 197.336
#                        min train dist: 95.5203
#                                  RT = 623.86
# Epoch 1995, step 14,     training dist: 180.411
#                             val dist: 197.346
#                       training loss: 12394.9
#                      validation loss: 17504.4
#                   min validation dist: 197.336
#                        min train dist: 95.5203
#                                  RT = 624.01
# Epoch 1996, step 11,     training dist: 232.856
#                             val dist: 197.262
#                       training loss: 2904.52
#                      validation loss: 17513.2
#                   min validation dist: 197.262
#                        min train dist: 95.5203
#                                  RT = 624.17
# Epoch 1997, step 8,     training dist: 211.675
#                             val dist: 197.252
#                       training loss: 6307.81
#                      validation loss: 17511
#                   min validation dist: 197.252
#                        min train dist: 95.5203
#                                  RT = 624.33
# Epoch 1998, step 5,     training dist: 222.29
#                             val dist: 197.202
#                       training loss: 7117.18
#                      validation loss: 17509.8
#                   min validation dist: 197.202
#                        min train dist: 95.5203
#                                  RT = 624.52
# Epoch 1999, step 2,     training dist: 178.639
#                             val dist: 197.141
#                       training loss: 2629.44
#                      validation loss: 17518.1
#                   min validation dist: 197.141
#                        min train dist: 95.5203
#                                  RT = 624.70
# Epoch 1999, step 102,     training dist: 291.54
#                             val dist: 197.164
#                       training loss: 7861.59
#                      validation loss: 17495.2
#                   min validation dist: 197.141
#                        min train dist: 95.5203
#                                  RT = 624.87

# %%
test_preds, testDiff, test_inframe = session.run([predict_op, totDiff, in_im_hat], feed_dict= {x: X_test, y: Y_test, y_in_img: Y_in_image_test})
# print(test_inframe)
def print_n_classifs(n, ims, labels, preds, in_im_pred):
    locs = np.random.choice(range(len(ims)), n, replace= False)
    
    for i in locs:
       
        f = plt.figure(figsize=(15,15))
        #f.subplot(121)
        ax = f.add_subplot(121)
        ax2 = f.add_subplot(122)
        pts = preds[i]
        for feature in key_loc_pairs.keys():
            loc = key_loc_pairs[feature]
#             if (np.array(loc) <= 0).any():
#                 continue
            if in_im_pred[i][loc] == False:
                continue
            x,y = pts[loc]
            if x < 0 or y < 0:
                continue
            ax.scatter(x,y, label= feature)
            ax2.scatter(x,y, label= feature)
        ax.imshow(ims[i])
        ax2.imshow(ims[i])
        ax2.legend()
        plt.show()
        
        
        plt.figure()
        pts = labels[i]
        for feature in key_loc_pairs.keys():
            loc = key_loc_pairs[feature]
            x,y = pts[loc]
            if x > 0 or y > 0:
                plt.scatter(x,y, label= feature)
        plt.imshow(ims[i])
        plt.legend()
        plt.show()
        
n = 1
np.random.seed(42)
print_n_classifs(n, X_test_ims, Y_test, test_preds, test_inframe)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-0d6f18f9f8c5> in <module>()
#      40 n = 1
#      41 np.random.seed(42)
# ---> 42 print_n_classifs(n, X_test_ims, Y_test, test_preds, test_inframe)
#
# <ipython-input-54-0d6f18f9f8c5> in print_n_classifs(n, ims, labels, preds, in_im_pred)
#       5
#       6     for i in locs:
# ----> 7         if in_im_pred[i] == False:
#       8             continue
#       9         f = plt.figure(figsize=(15,15))
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
num = 5
train_preds, trainDiff = session.run([predict_op, totDiff], feed_dict= {x: X_train, y: Y_train})
print_n_classifs(n, X_train_ims, Y_train, train_preds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-fe507278b9c2> in <module>()
#       1 num = 5
#       2 train_preds, trainDiff = session.run([predict_op, totDiff], feed_dict= {x: X_train, y: Y_train})
# ----> 3 print_n_classifs(n, X_train_ims, Y_train, train_preds)
#
# TypeError: print_n_classifs() missing 1 required positional argument: 'in_im_pred'
